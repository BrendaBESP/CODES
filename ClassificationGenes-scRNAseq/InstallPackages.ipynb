# %% [markdown]
# BESP
#
# 23  04 11
#
# Bimodal cell cycle and size related genes
#
# Alex Casar / David Goode
#
# ****
#
# **Installed packages**

# %% [markdown]
# ## Install packages

# %% [markdown]
# The list of commands to create the packages file

# %%
# %%R
# # Locate and stand the more usefull default library in colab
# #.libPaths('usr/lib/R/site-library/')
# # Pre installation
# devtools::install_github('Malindrie/scShapes')
# devtools::install_github('satijalab/seurat-data')
#
# # These two packages need the last two commands for succes
# install.packages("SeuratData")
# install.packages("BiocParallel")
#
# install.packages("dplyr")
# install.packages("Seurat")
# install.packages("patchwork")
# install.packages("Matrix")
# install.packages('BiocManager')
# BiocManager::install('limma')
# install.packages("vioplot")
# install.packages("ggplot2")
# install.packages("tidyverse")
# BiocManager::install("clusterProfiler")
# BiocManager::install("org.Hs.eg.db")
#
# install.packages("BimodalIndex")
# BiocManager::install("clusterProfiler")
# BiocManager::install("org.Hs.eg.db")
#
# install.packages("pheatmap")
# install.packages("reshape")
# install.packages("viridis")
#
#
# install.packages("iZID")
#
# install.packages("DescTools")   # For %like% operator
#
#
# # Problems with R version
# #install.packages("edgeR")
# Out:
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Downloading GitHub repo Malindrie/scShapes@HEAD
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing 18 packages: mvtnorm, bdsmatrix, numDeriv, Rcpp, formatR, futile.options, lambda.r, bbmle, coda, plyr, BH, snow, futile.logger, emdbook, BiocParallel, dgof, VGAM, pscl
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/mvtnorm_1.1-3.tar.gz'
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: Content type 'application/x-gzip'
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]:  length 166421 bytes (162 KB)
#
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# WARNING:rpy2.rinterface_lib.callbacks:R[write to console]: =
# ...

# %%
# Compress and save final libs
# !tar -cf libraryD.tar /usr/lib/R/site-library
# %cp libraryD.tar drive/MyDrive/MELBOURN/lib/    # The file that contains the final set of packages
# !rm libraryD.tar
# Out:
# tar: Removing leading `/' from member names
